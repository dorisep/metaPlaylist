# %%
import csv
import os

from spotify_client import *

# %%
client_id = "6f2a7816998d4d7e992f1dba605ccd33"
client_secret = "f1029bcc83634b4c9497ec0bcd701498"
user_id = "ed.doris"
endpoint = "https://api.spotify.com/v1/users/{user_id}/playlists"
csv_path = os.path.join("..", "data", "albums_2020.csv")
albums=[]
artist=[]
a={}

# %%
with open(csv_path, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        artist.append(row['artist'])
        albums.append(row['album'])

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
albums = albums[0:100]
print(len(albums))
# Out:
# 100

# %%
for al in (albums):
    spotify.search({"album":al}, search_type="album")
# Out:
# q=album%3AFetch+the+Bolt+Cutters&type=album
# https://api.spotify.com/v1/search?q=album%3AFetch+the+Bolt+Cutters&type=album
# 200
# q=album%3ARough+and+Rowdy+Ways&type=album
# https://api.spotify.com/v1/search?q=album%3ARough+and+Rowdy+Ways&type=album
# 200
# q=album%3ASet+My+Heart+on+Fire+Immediately&type=album
# https://api.spotify.com/v1/search?q=album%3ASet+My+Heart+on+Fire+Immediately&type=album
# 200
# q=album%3ASex%2C+Death+%26+The+Infinite+Void&type=album
# https://api.spotify.com/v1/search?q=album%3ASex%2C+Death+%26+The+Infinite+Void&type=album
# 200
# q=album%3APunisher&type=album
# https://api.spotify.com/v1/search?q=album%3APunisher&type=album
# 200
# q=album%3Agr%C3%A6&type=album
# https://api.spotify.com/v1/search?q=album%3Agr%C3%A6&type=album
# 200
# q=album%3ARTJ4&type=album
# https://api.spotify.com/v1/search?q=album%3ARTJ4&type=album
# 200
# q=album%3ASawayama&type=album
# https://api.spotify.com/v1/search?q=album%3ASawayama&type=album
# 200
# ...

# %%
print(a)
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=album%3ANever+Will&type=album&offset=0&limit=20', 'items': [{'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZxZlO7oWCSYMXhehpyMvE'}, 'href': 'https://api.spotify.com/v1/artists/0ZxZlO7oWCSYMXhehpyMvE', 'id': '0ZxZlO7oWCSYMXhehpyMvE', 'name': 'COIN', 'type': 'artist', 'uri': 'spotify:artist:0ZxZlO7oWCSYMXhehpyMvE'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK',
# ...
