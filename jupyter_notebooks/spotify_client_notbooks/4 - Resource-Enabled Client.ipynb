# %%
import json
import requests
import base64
import datetime
from urllib.parse import urlencode
# from secrets import spotify_user_id

# %%
client_id = "6f2a7816998d4d7e992f1dba605ccd33"
client_secret = "f1029bcc83634b4c9497ec0bcd701498"

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url ="https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
        "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
                return {
            "grant_type": "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")   
#             return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
        "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type="albums", version="v1"):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type = "albums")
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type = "artists")

    
    def search(self, query, search_type="album"):
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({
            "q":query, "type":search_type
        })

        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("Ignorance", search_type="album")
# Out:
# https://api.spotify.com/v1/search?q=Ignorance&type=album
# 200
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=Ignorance&type=album&offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/39ZEMGRv3pIYTYKEhr4Abu'},
#       'href': 'https://api.spotify.com/v1/artists/39ZEMGRv3pIYTYKEhr4Abu',
#       'id': '39ZEMGRv3pIYTYKEhr4Abu',
#       'name': 'The Weather Station',
#       'type': 'artist',
#       'uri': 'spotify:artist:39ZEMGRv3pIYTYKEhr4Abu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3KeR5BDM2giFr8zoSXBrgE'},
#     'href': 'https://api.spotify.com/v1/albums/3KeR5BDM2giFr8zoSXBrgE',
#     'id': '3KeR5BDM2giFr8zoSXBrgE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ec01f5a2f56180b6f6b634ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ec01f5a2f56180b6f6b634ec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ec01f5a2f56180b6f6b634ec',
#       'width': 64}],
#     'name': 'Ignorance',
#     'release_date': '2021-02-05',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3KeR5BDM2giFr8zoSXBrgE'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2p1fiYHYiXz9qi0JJyxBzN'},
#       'href': 'https://api.spotify.com/v1/artists/2p1fiYHYiXz9qi0JJyxBzN',
#       'id': '2p1fiYHYiXz9qi0JJyxBzN',
#       'name': 'Skepta',
#       'type': 'artist',
#       'uri': 'spotify:artist:2p1fiYHYiXz9qi0JJyxBzN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/22zpCX6Nb9ppOVklalvGec'},
#     'href': 'https://api.spotify.com/v1/albums/22zpCX6Nb9ppOVklalvGec',
#     'id': '22zpCX6Nb9ppOVklalvGec',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348f2487a18a735f457404eb9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248f2487a18a735f457404eb9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148f2487a18a735f457404eb9',
#       'width': 64}],
#     'name': 'Ignorance is Bliss',
#     'release_date': '2019-05-31',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:22zpCX6Nb9ppOVklalvGec'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UeVJTdCWGEFSSO9Tg9tiH'},
#       'href': 'https://api.spotify.com/v1/artists/0UeVJTdCWGEFSSO9Tg9tiH',
#       'id': '0UeVJTdCWGEFSSO9Tg9tiH',
#       'name': 'Sacred Reich',
#       'type': 'artist',
#       'uri': 'spotify:artist:0UeVJTdCWGEFSSO9Tg9tiH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6oIYHgssDkhfR0RgUoOyX0'},
#     'href': 'https://api.spotify.com/v1/albums/6oIYHgssDkhfR0RgUoOyX0',
#     'id': '6oIYHgssDkhfR0RgUoOyX0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736794dada696063d4e64c6c77',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026794dada696063d4e64c6c77',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516794dada696063d4e64c6c77',
#       'width': 64}],
#     'name': 'Ignorance & Surf Nicaragua',
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 24,
#     'type': 'album',
#     'uri': 'spotify:album:6oIYHgssDkhfR0RgUoOyX0'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00YTqRClk82aMchQQpYMd5'},
#       'href': 'https://api.spotify.com/v1/artists/00YTqRClk82aMchQQpYMd5',
#       'id': '00YTqRClk82aMchQQpYMd5',
#       'name': 'Our Last Night',
#       'type': 'artist',
#       'uri': 'spotify:artist:00YTqRClk82aMchQQpYMd5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2XGFVYNHi4z3zwd3e2kNO1'},
#     'href': 'https://api.spotify.com/v1/albums/2XGFVYNHi4z3zwd3e2kNO1',
#     'id': '2XGFVYNHi4z3zwd3e2kNO1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cf877b9a314deeedc233d6be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cf877b9a314deeedc233d6be',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cf877b9a314deeedc233d6be',
#       'width': 64}],
#     'name': 'Age Of Ignorance (Deluxe Edition)',
#     'release_date': '2013-06-18',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:2XGFVYNHi4z3zwd3e2kNO1'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00YTqRClk82aMchQQpYMd5'},
#       'href': 'https://api.spotify.com/v1/artists/00YTqRClk82aMchQQpYMd5',
#       'id': '00YTqRClk82aMchQQpYMd5',
#       'name': 'Our Last Night',
#       'type': 'artist',
#       'uri': 'spotify:artist:00YTqRClk82aMchQQpYMd5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/68vzj38mZrrQTQrECt1dWo'},
#     'href': 'https://api.spotify.com/v1/albums/68vzj38mZrrQTQrECt1dWo',
#     'id': '68vzj38mZrrQTQrECt1dWo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27338b1f1e5a2b37cb427d9bf45',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0238b1f1e5a2b37cb427d9bf45',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485138b1f1e5a2b37cb427d9bf45',
#       'width': 64}],
#     'name': 'Ignorance Is Bliss',
#     'release_date': '2020-08-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:68vzj38mZrrQTQrECt1dWo'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MvPBsOMK4PW1shySFAomj'},
#       'href': 'https://api.spotify.com/v1/artists/0MvPBsOMK4PW1shySFAomj',
#       'id': '0MvPBsOMK4PW1shySFAomj',
#       'name': 'Digital Bliss',
#       'type': 'artist',
#       'uri': 'spotify:artist:0MvPBsOMK4PW1shySFAomj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4fgmOKG6ZYWrzu34Ie3oTF'},
#     'href': 'https://api.spotify.com/v1/albums/4fgmOKG6ZYWrzu34Ie3oTF',
#     'id': '4fgmOKG6ZYWrzu34Ie3oTF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273df125944d6e6ae3e93294a34',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02df125944d6e6ae3e93294a34',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851df125944d6e6ae3e93294a34',
#       'width': 64}],
#     'name': 'Blissful Ignorance',
#     'release_date': '2020-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4fgmOKG6ZYWrzu34Ie3oTF'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DICBAYiaIMh5MulqwCtET'},
#       'href': 'https://api.spotify.com/v1/artists/7DICBAYiaIMh5MulqwCtET',
#       'id': '7DICBAYiaIMh5MulqwCtET',
#       'name': 'AK',
#       'type': 'artist',
#       'uri': 'spotify:artist:7DICBAYiaIMh5MulqwCtET'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2MSo2SOdAdyPvIXmIWcet1'},
#     'href': 'https://api.spotify.com/v1/albums/2MSo2SOdAdyPvIXmIWcet1',
#     'id': '2MSo2SOdAdyPvIXmIWcet1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730b212f207f8c5a23048b48bd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020b212f207f8c5a23048b48bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510b212f207f8c5a23048b48bd',
#       'width': 64}],
#     'name': 'Ignorance Is Bliss',
#     'release_date': '2019-06-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2MSo2SOdAdyPvIXmIWcet1'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ODTjg0iTHX1QxBeRNI6nT'},
#       'href': 'https://api.spotify.com/v1/artists/2ODTjg0iTHX1QxBeRNI6nT',
#       'id': '2ODTjg0iTHX1QxBeRNI6nT',
#       'name': 'Katori Walker',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ODTjg0iTHX1QxBeRNI6nT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7M5hwj8rTk1mDghHWbVA02'},
#     'href': 'https://api.spotify.com/v1/albums/7M5hwj8rTk1mDghHWbVA02',
#     'id': '7M5hwj8rTk1mDghHWbVA02',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b701194aae490a0816147f7f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b701194aae490a0816147f7f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b701194aae490a0816147f7f',
#       'width': 64}],
#     'name': 'Ignorance',
#     'release_date': '2018-04-27',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:7M5hwj8rTk1mDghHWbVA02'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lwqaaRdw4yOfHYzr466E6'},
#       'href': 'https://api.spotify.com/v1/artists/0lwqaaRdw4yOfHYzr466E6',
#       'id': '0lwqaaRdw4yOfHYzr466E6',
#       'name': 'Gerald Vale',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lwqaaRdw4yOfHYzr466E6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6wpcD97iqfSyXF47rvIYHh'},
#     'href': 'https://api.spotify.com/v1/albums/6wpcD97iqfSyXF47rvIYHh',
#     'id': '6wpcD97iqfSyXF47rvIYHh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731dc8064698580bec2b6bc81a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021dc8064698580bec2b6bc81a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511dc8064698580bec2b6bc81a',
#       'width': 64}],
#     'name': 'Blissful Ignorance',
#     'release_date': '2020-08-19',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6wpcD97iqfSyXF47rvIYHh'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TCuSgJzNaRyxjbvvLjBK3'},
#       'href': 'https://api.spotify.com/v1/artists/0TCuSgJzNaRyxjbvvLjBK3',
#       'id': '0TCuSgJzNaRyxjbvvLjBK3',
#       'name': 'Lollia',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TCuSgJzNaRyxjbvvLjBK3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6LAUnmeTObvE3N8Us7OPDa'},
#     'href': 'https://api.spotify.com/v1/albums/6LAUnmeTObvE3N8Us7OPDa',
#     'id': '6LAUnmeTObvE3N8Us7OPDa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273120c9ac42e886ca7a263ec8b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02120c9ac42e886ca7a263ec8b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851120c9ac42e886ca7a263ec8b',
#       'width': 64}],
#     'name': 'Ignorance',
#     'release_date': '2021-01-08',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6LAUnmeTObvE3N8Us7OPDa'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/696x5uEm1nV6xucEZNAbzH'},
#       'href': 'https://api.spotify.com/v1/artists/696x5uEm1nV6xucEZNAbzH',
#       'id': '696x5uEm1nV6xucEZNAbzH',
#       'name': 'Emily Zeck',
#       'type': 'artist',
#       'uri': 'spotify:artist:696x5uEm1nV6xucEZNAbzH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6teRzD3N6CNwWYHgHQyOPc'},
#     'href': 'https://api.spotify.com/v1/albums/6teRzD3N6CNwWYHgHQyOPc',
#     'id': '6teRzD3N6CNwWYHgHQyOPc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273efb6e5e7d3d5ec5609ca6266',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02efb6e5e7d3d5ec5609ca6266',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851efb6e5e7d3d5ec5609ca6266',
#       'width': 64}],
#     'name': 'Blissful Ignorance',
#     'release_date': '2020-10-23',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:6teRzD3N6CNwWYHgHQyOPc'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5uVgoepJHC3fbOohI5gXc4'},
#       'href': 'https://api.spotify.com/v1/artists/5uVgoepJHC3fbOohI5gXc4',
#       'id': '5uVgoepJHC3fbOohI5gXc4',
#       'name': 'Jung Jin Woo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5uVgoepJHC3fbOohI5gXc4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5GjOJ4ITDdrqpzlRjYCWMX'},
#     'href': 'https://api.spotify.com/v1/albums/5GjOJ4ITDdrqpzlRjYCWMX',
#     'id': '5GjOJ4ITDdrqpzlRjYCWMX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395b189f922fc57f98c798f5f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295b189f922fc57f98c798f5f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195b189f922fc57f98c798f5f',
#       'width': 64}],
#     'name': 'Ignorance',
#     'release_date': '2019-12-04',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:5GjOJ4ITDdrqpzlRjYCWMX'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2u3gM4gmb4fw6RKKWfdQBf'},
#       'href': 'https://api.spotify.com/v1/artists/2u3gM4gmb4fw6RKKWfdQBf',
#       'id': '2u3gM4gmb4fw6RKKWfdQBf',
#       'name': 'Anahi Burge',
#       'type': 'artist',
#       'uri': 'spotify:artist:2u3gM4gmb4fw6RKKWfdQBf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4KCJuaLZnfx1CFD4F7ZTHc'},
#     'href': 'https://api.spotify.com/v1/albums/4KCJuaLZnfx1CFD4F7ZTHc',
#     'id': '4KCJuaLZnfx1CFD4F7ZTHc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738f6dcb4f613b674cef6373a4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028f6dcb4f613b674cef6373a4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518f6dcb4f613b674cef6373a4',
#       'width': 64}],
#     'name': 'Ignorance',
#     'release_date': '2021-02-06',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4KCJuaLZnfx1CFD4F7ZTHc'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4k8ZMbCLduQVguxDIJgDse'},
#       'href': 'https://api.spotify.com/v1/artists/4k8ZMbCLduQVguxDIJgDse',
#       'id': '4k8ZMbCLduQVguxDIJgDse',
#       'name': 'TJ Rehmi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4k8ZMbCLduQVguxDIJgDse'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7COIx5qWLHTOUThP18CdtJ'},
#     'href': 'https://api.spotify.com/v1/albums/7COIx5qWLHTOUThP18CdtJ',
#     'id': '7COIx5qWLHTOUThP18CdtJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d9b4e6f14bc805515b60823d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d9b4e6f14bc805515b60823d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d9b4e6f14bc805515b60823d',
#       'width': 64}],
#     'name': 'Axis of Ignorance',
#     'release_date': '2009-07-27',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7COIx5qWLHTOUThP18CdtJ'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4l9ufn9GC6LLYXvIanDlLd'},
#       'href': 'https://api.spotify.com/v1/artists/4l9ufn9GC6LLYXvIanDlLd',
#       'id': '4l9ufn9GC6LLYXvIanDlLd',
#       'name': 'Face To Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:4l9ufn9GC6LLYXvIanDlLd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2RIl2ZVbxQ7BSuEhbLVmzk'},
#     'href': 'https://api.spotify.com/v1/albums/2RIl2ZVbxQ7BSuEhbLVmzk',
#     'id': '2RIl2ZVbxQ7BSuEhbLVmzk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2d6dd84ae630bf5f1581688',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2d6dd84ae630bf5f1581688',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2d6dd84ae630bf5f1581688',
#       'width': 64}],
#     'name': 'Ignorance Is Bliss (Bonus Tracks)',
#     'release_date': '1999-07-27',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:2RIl2ZVbxQ7BSuEhbLVmzk'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yvSVvz7a5Sofqj9HRMxTZ'},
#       'href': 'https://api.spotify.com/v1/artists/0yvSVvz7a5Sofqj9HRMxTZ',
#       'id': '0yvSVvz7a5Sofqj9HRMxTZ',
#       'name': 'Replause',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yvSVvz7a5Sofqj9HRMxTZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4LAVadooPRG7cUXHcjhUQU'},
#     'href': 'https://api.spotify.com/v1/albums/4LAVadooPRG7cUXHcjhUQU',
#     'id': '4LAVadooPRG7cUXHcjhUQU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735c7121b52b85e1dca07fa356',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025c7121b52b85e1dca07fa356',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515c7121b52b85e1dca07fa356',
#       'width': 64}],
#     'name': 'Ignorance the World',
#     'release_date': '2021-01-26',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4LAVadooPRG7cUXHcjhUQU'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q3f2YYH4gQxWFS3WY5G3j'},
#       'href': 'https://api.spotify.com/v1/artists/4Q3f2YYH4gQxWFS3WY5G3j',
#       'id': '4Q3f2YYH4gQxWFS3WY5G3j',
#       'name': 'Soko',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Q3f2YYH4gQxWFS3WY5G3j'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4OlJn222cAXyQbEBKX9L5A'},
#     'href': 'https://api.spotify.com/v1/albums/4OlJn222cAXyQbEBKX9L5A',
#     'id': '4OlJn222cAXyQbEBKX9L5A',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273400feeb57ea22e393558c39c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02400feeb57ea22e393558c39c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851400feeb57ea22e393558c39c',
#       'width': 64}],
#     'name': 'Sweet Sound of Ignorance',
#     'release_date': '2019-03-26',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4OlJn222cAXyQbEBKX9L5A'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7AwjxGNLsFAov9qk9w1nwm'},
#       'href': 'https://api.spotify.com/v1/artists/7AwjxGNLsFAov9qk9w1nwm',
#       'id': '7AwjxGNLsFAov9qk9w1nwm',
#       'name': 'Fluids',
#       'type': 'artist',
#       'uri': 'spotify:artist:7AwjxGNLsFAov9qk9w1nwm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0OGtN36eCSYbpeqyJUseKm'},
#     'href': 'https://api.spotify.com/v1/albums/0OGtN36eCSYbpeqyJUseKm',
#     'id': '0OGtN36eCSYbpeqyJUseKm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cc0687f659379af849b079cb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cc0687f659379af849b079cb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cc0687f659379af849b079cb',
#       'width': 64}],
#     'name': 'Ignorance Exalted',
#     'release_date': '2020-05-01',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:0OGtN36eCSYbpeqyJUseKm'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Vb15td3iKkAzdGD5Sj9Ky'},
#       'href': 'https://api.spotify.com/v1/artists/0Vb15td3iKkAzdGD5Sj9Ky',
#       'id': '0Vb15td3iKkAzdGD5Sj9Ky',
#       'name': 'NateWantsToBattle',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Vb15td3iKkAzdGD5Sj9Ky'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2vElbSsJonOCi11XAN8Ke4'},
#     'href': 'https://api.spotify.com/v1/albums/2vElbSsJonOCi11XAN8Ke4',
#     'id': '2vElbSsJonOCi11XAN8Ke4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733ff1e0626d677cfb057cae11',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023ff1e0626d677cfb057cae11',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513ff1e0626d677cfb057cae11',
#       'width': 64}],
#     'name': 'Ignorance',
#     'release_date': '2016-01-19',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2vElbSsJonOCi11XAN8Ke4'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lydMCYBhZYnA5d54vrmzr'},
#       'href': 'https://api.spotify.com/v1/artists/5lydMCYBhZYnA5d54vrmzr',
#       'id': '5lydMCYBhZYnA5d54vrmzr',
#       'name': 'Sam Sixx',
#       'type': 'artist',
#       'uri': 'spotify:artist:5lydMCYBhZYnA5d54vrmzr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5Hpx5RGVf6Lt5r9LfHY5QZ'},
#     'href': 'https://api.spotify.com/v1/albums/5Hpx5RGVf6Lt5r9LfHY5QZ',
#     'id': '5Hpx5RGVf6Lt5r9LfHY5QZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27314756f9c65a5eab3b9bc0359',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0214756f9c65a5eab3b9bc0359',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485114756f9c65a5eab3b9bc0359',
#       'width': 64}],
#     'name': 'Blissful Ignorance',
#     'release_date': '2020-01-05',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:5Hpx5RGVf6Lt5r9LfHY5QZ'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Ignorance&type=album&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 747}}

# %%
spotify.get_artist('3g2kUQ6tHLLbmkV7T4GPtL')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#  'followers': {'href': None, 'total': 721593},
#  'genres': ['art pop',
#   'chamber pop',
#   'lilith',
#   'permanent wave',
#   'piano rock',
#   'pop rock',
#   'singer-songwriter'],
#  'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#  'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/0e8127b1cf85ed41361897d02aede5298749d3f8',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/4f529b5f793fe9e9e8f08d428b94bfa834cb6db4',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/bf18ad78ea67ee490a255de22f91d2b4a550a456',
#    'width': 160}],
#  'name': 'Fiona Apple',
#  'popularity': 66,
#  'type': 'artist',
#  'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}

# %%
spotify.get_album("0fO1KemWL2uCCQmM22iKlj")
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#    'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#    'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#    'name': 'Fiona Apple',
#    'type': 'artist',
#    'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'copyrights': [{'text': '(P) 2020 Epic Records, a division of Sony Music Entertainment',
#    'type': 'P'}],
#  'external_ids': {'upc': '886448398486'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0fO1KemWL2uCCQmM22iKlj'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/0fO1KemWL2uCCQmM22iKlj',
#  'id': '0fO1KemWL2uCCQmM22iKlj',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273841292c1316c4bf85447bcd9',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02841292c1316c4bf85447bcd9',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851841292c1316c4bf85447bcd9',
#    'width': 64}],
#  'label': 'Epic',
#  'name': 'Fetch The Bolt Cutters',
#  'popularity': 64,
#  'release_date': '2020-04-17',
#  'release_date_precision': 'day',
#  'total_tracks': 13,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/0fO1KemWL2uCCQmM22iKlj/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237713,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73SBAGI4fPFm4VkB3NjXq8'},
#     'href': 'https://api.spotify.com/v1/tracks/73SBAGI4fPFm4VkB3NjXq8',
#     'id': '73SBAGI4fPFm4VkB3NjXq8',
#     'is_local': False,
#     'name': 'I Want You To Love Me',
#     'preview_url': 'https://p.scdn.co/mp3-preview/a2e09a985bd5c78ae6d0132a23f3c8c8feea4de0?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:73SBAGI4fPFm4VkB3NjXq8'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 248603,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2pDKE8Q40TDGPl1O11DKKn'},
#     'href': 'https://api.spotify.com/v1/tracks/2pDKE8Q40TDGPl1O11DKKn',
#     'id': '2pDKE8Q40TDGPl1O11DKKn',
#     'is_local': False,
#     'name': 'Shameika',
#     'preview_url': 'https://p.scdn.co/mp3-preview/a6ad859a16f25fba18b7386412708c01d4bfe2b3?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2pDKE8Q40TDGPl1O11DKKn'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 298457,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4SdubskbLiOkpsIjRVVsya'},
#     'href': 'https://api.spotify.com/v1/tracks/4SdubskbLiOkpsIjRVVsya',
#     'id': '4SdubskbLiOkpsIjRVVsya',
#     'is_local': False,
#     'name': 'Fetch The Bolt Cutters',
#     'preview_url': 'https://p.scdn.co/mp3-preview/833e7267e5908e8d76e7fbb63a86e77825967761?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4SdubskbLiOkpsIjRVVsya'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 201352,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/12WhIX6MvI93bS3wPSStSY'},
#     'href': 'https://api.spotify.com/v1/tracks/12WhIX6MvI93bS3wPSStSY',
#     'id': '12WhIX6MvI93bS3wPSStSY',
#     'is_local': False,
#     'name': 'Under The Table',
#     'preview_url': 'https://p.scdn.co/mp3-preview/76efff2d449e98620d4ee93c60d2270a69eff455?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:12WhIX6MvI93bS3wPSStSY'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 289229,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5hnOzmFuGltDDAm008jFDh'},
#     'href': 'https://api.spotify.com/v1/tracks/5hnOzmFuGltDDAm008jFDh',
#     'id': '5hnOzmFuGltDDAm008jFDh',
#     'is_local': False,
#     'name': 'Relay',
#     'preview_url': 'https://p.scdn.co/mp3-preview/86f416caa61829760d9ab4a352c19a734685a966?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5hnOzmFuGltDDAm008jFDh'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 222307,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/17QLp5uadHptxnmq9clK8U'},
#     'href': 'https://api.spotify.com/v1/tracks/17QLp5uadHptxnmq9clK8U',
#     'id': '17QLp5uadHptxnmq9clK8U',
#     'is_local': False,
#     'name': 'Rack of His',
#     'preview_url': 'https://p.scdn.co/mp3-preview/c606c8b86964a3d650fd080bb325e53ec863d815?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:17QLp5uadHptxnmq9clK8U'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 332404,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1YsWyCYqpA8uZaR9SfYAnY'},
#     'href': 'https://api.spotify.com/v1/tracks/1YsWyCYqpA8uZaR9SfYAnY',
#     'id': '1YsWyCYqpA8uZaR9SfYAnY',
#     'is_local': False,
#     'name': 'Newspaper',
#     'preview_url': 'https://p.scdn.co/mp3-preview/c5261ba0e5b61353a1e6e11153cffd201631096d?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1YsWyCYqpA8uZaR9SfYAnY'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 325373,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0jH0IsCBGackT3RmHBbSUI'},
#     'href': 'https://api.spotify.com/v1/tracks/0jH0IsCBGackT3RmHBbSUI',
#     'id': '0jH0IsCBGackT3RmHBbSUI',
#     'is_local': False,
#     'name': 'Ladies',
#     'preview_url': 'https://p.scdn.co/mp3-preview/36aa40927178163cd935d17db7761194dff90924?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0jH0IsCBGackT3RmHBbSUI'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 206262,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2OQpQTRogZ1AhnUHJiT9Nb'},
#     'href': 'https://api.spotify.com/v1/tracks/2OQpQTRogZ1AhnUHJiT9Nb',
#     'id': '2OQpQTRogZ1AhnUHJiT9Nb',
#     'is_local': False,
#     'name': 'Heavy Balloon',
#     'preview_url': 'https://p.scdn.co/mp3-preview/3904388b84f21fccde6969f5d2dca66da92b3700?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2OQpQTRogZ1AhnUHJiT9Nb'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 239310,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7eGoc6UmwiRAVnilTZajNC'},
#     'href': 'https://api.spotify.com/v1/tracks/7eGoc6UmwiRAVnilTZajNC',
#     'id': '7eGoc6UmwiRAVnilTZajNC',
#     'is_local': False,
#     'name': 'Cosmonauts',
#     'preview_url': 'https://p.scdn.co/mp3-preview/90e4a9249f2892b6e938725fd077bf11cfd8deb1?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7eGoc6UmwiRAVnilTZajNC'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 163720,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5BBWr1LUsCH1tECJLAUGnP'},
#     'href': 'https://api.spotify.com/v1/tracks/5BBWr1LUsCH1tECJLAUGnP',
#     'id': '5BBWr1LUsCH1tECJLAUGnP',
#     'is_local': False,
#     'name': 'For Her',
#     'preview_url': 'https://p.scdn.co/mp3-preview/a433823bd1820d8b93bdec8caaa0a0eeabc28243?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:5BBWr1LUsCH1tECJLAUGnP'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 160324,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4baGw8dAfqNl7RrmlMtzb5'},
#     'href': 'https://api.spotify.com/v1/tracks/4baGw8dAfqNl7RrmlMtzb5',
#     'id': '4baGw8dAfqNl7RrmlMtzb5',
#     'is_local': False,
#     'name': 'Drumset',
#     'preview_url': 'https://p.scdn.co/mp3-preview/3e33699f3703defb944d943b24ee3e8fa2b9a543?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:4baGw8dAfqNl7RrmlMtzb5'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g2kUQ6tHLLbmkV7T4GPtL'},
#       'href': 'https://api.spotify.com/v1/artists/3g2kUQ6tHLLbmkV7T4GPtL',
#       'id': '3g2kUQ6tHLLbmkV7T4GPtL',
#       'name': 'Fiona Apple',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g2kUQ6tHLLbmkV7T4GPtL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 189082,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6VU4Ys4rbbbwJ84g1ZuYA5'},
#     'href': 'https://api.spotify.com/v1/tracks/6VU4Ys4rbbbwJ84g1ZuYA5',
#     'id': '6VU4Ys4rbbbwJ84g1ZuYA5',
#     'is_local': False,
#     'name': 'On I Go',
#     'preview_url': 'https://p.scdn.co/mp3-preview/154c46c0767b2b5373fdf05a6fac4c8ed306c941?cid=6f2a7816998d4d7e992f1dba605ccd33',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:6VU4Ys4rbbbwJ84g1ZuYA5'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 13},
#  'type': 'album',
#  'uri': 'spotify:album:0fO1KemWL2uCCQmM22iKlj'}
